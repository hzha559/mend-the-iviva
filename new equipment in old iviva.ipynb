# %%
####use to new equipment in old version Iviva
import pandas as pd
from time import sleep
from selenium import webdriver
from selenium.webdriver import ActionChains
# from selenium.interactions import Actions
# from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
import time
import os, sys
import array as arr
import numpy as np
import datetime as dt
from selenium.webdriver.common.keys import Keys

#########################define everthing in this section##############################################
ipaddr="http://100queensiviva.dyndns.org:8889/Apps/IBMS/equipment.create"
login_id="admin"
password=""
csv='CreateEquipment.csv'
zone="QC"

########################################################################################################
##########be careful if you need to change anything below#############################################
options = webdriver.ChromeOptions()
options.add_argument('ignore-certificate-errors')
driver = webdriver.Chrome(options=options)
driver.get(ipaddr) #change to 100Q site
Username = driver.find_element_by_xpath('//*[@id="loginid"]');
Username.send_keys(login_id); #place username here
PW = driver.find_element_by_xpath('//*[@id="password"]');
PW.send_keys(password); #place password here
driver.implicitly_wait(100);
button = driver.find_element_by_id('login');
button.click();
a = pd.read_csv(csv)

for i in a.index:
    try:
        driver.get(ipaddr) #change to 100Q site
        IBMS = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/form/div/table/tbody/tr/td/div/div[2]/table/tbody/tr[1]/td[2]/span/span/span/input');
        IBMS.send_keys(zone); #change ibms zone here
        time.sleep(1)
        IBMS.click()
        driver.implicitly_wait(1);
        IBMS.send_keys(Keys.ENTER);
        driver.implicitly_wait(1);

        Asset = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/form/div/table/tbody/tr/td/div/div[2]/table/tbody/tr[2]/td[2]/span/span/span[1]/input');
        Asset.send_keys(a.Equipment[i]); #change in csv file
        time.sleep(1)
        Asset.click()
        driver.implicitly_wait(1);
        Asset.send_keys(Keys.ENTER);
        driver.implicitly_wait(1);

        Template = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/form/div/table/tbody/tr/td/div/div[2]/table/tbody/tr[3]/td[2]/span/span/span/input')
        Template.send_keys(a.Template[i]); #change in csv file
        time.sleep(1)
        Template.click()
        driver.implicitly_wait(1);
        Template.send_keys(Keys.ENTER);
        driver.implicitly_wait(1);
        #print(Template.get_attribute('value'))
        #print(IBMS.get_attribute('value'))
        #print(Asset.get_attribute('value'))
        if ((Template.get_attribute('value')=="" or IBMS.get_attribute('value')=="") or Asset.get_attribute('value')==""):
            print("can't new this equipment because something can't be found 1, iteration: "+str(i))
            continue
        elif((Template.get_attribute('value')!=a.Template[i] or IBMS.get_attribute('value')!=zone) or Asset.get_attribute('value')!=a.Equipment[i]):
            print("can't new this equipment because something can't be found 2, iteration: "+str(i))
            continue
        else:
            Click2 = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/form/div/table/tbody/tr/td/div/div[2]/table/tbody/tr[5]/td[2]/input')
            #Click2.click()
        time.sleep(1)
    except:
        print("fail this iteration for no obvious reason, please check, iteration: "+str(i))
# Out:
# can't new this equipment because something can't be found 1
# can't new this equipment because something can't be found 1
# can't new this equipment because something can't be found 1
# can't new this equipment because something can't be found 1
# can't new this equipment because something can't be found 1
# can't new this equipment because something can't be found 1
# can't new this equipment because something can't be found 1
# can't new this equipment because something can't be found 1
# can't new this equipment because something can't be found 1
# can't new this equipment because something can't be found 1
# can't new this equipment because something can't be found 2
# can't new this equipment because something can't be found 1
# can't new this equipment because something can't be found 1
# can't new this equipment because something can't be found 1
# can't new this equipment because something can't be found 1
# can't new this equipment because something can't be found 1
# ...
